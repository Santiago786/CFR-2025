# %% [markdown]
# ### Project plot!
#
# Have your code for your project plot here. All data is in the ../Data/CFR_project_data folder

# %%
import pandas as pd 
data = pd.read_csv('../Data/CFR_project_data/naeem/mergers_0.csv')

# %%
data
# Out:
#       Time Since Last Major Merger [Gyr]  Number of Major Mergers
# 0                              12.361172                        2
# 1                              12.698000                        2
# 2                              13.230112                        1
# 3                              13.800000                        0
# 4                              13.800000                        0
# ...                                  ...                      ...
# 9995                           13.800000                        0
# 9996                           13.800000                        0
# 9997                           13.800000                        0
# 9998                           13.800000                        0
# 9999                           13.800000                        0
#
# [10000 rows x 2 columns]

# %%
data2=pd.read_csv('../Data/CFR_project_data/naeem/mergers_0.44.csv')

# %%
data2
# Out:
#       Time Since Last Major Merger [Gyr]  Number of Major Mergers
# 0                              12.031033                        1
# 1                              11.564821                        4
# 2                              13.800000                        0
# 3                              13.800000                        0
# 4                              13.800000                        0
# ...                                  ...                      ...
# 9995                           13.800000                        0
# 9996                           13.800000                        0
# 9997                           13.800000                        0
# 9998                           13.800000                        0
# 9999                           13.800000                        0
#
# [10000 rows x 2 columns]

# %%
data3=pd.read_csv('../Data/CFR_project_data/naeem/mergers_1.csv')

# %%
data3
# Out:
#       Time Since Last Major Merger [Gyr]  Number of Major Mergers
# 0                              12.445128                        1
# 1                              13.800000                        0
# 2                              13.800000                        0
# 3                              13.800000                        0
# 4                              13.800000                        0
# ...                                  ...                      ...
# 9995                           13.800000                        0
# 9996                           13.800000                        0
# 9997                           13.800000                        0
# 9998                           13.800000                        0
# 9999                           13.800000                        0
#
# [10000 rows x 2 columns]

# %%
num_major_mergers= data['Number of Major Mergers']

# %%
num_major_mergers
# Out:
# 0       2
# 1       2
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    0
# 9998    0
# 9999    0
# Name: Number of Major Mergers, Length: 10000, dtype: int64

# %%
major_merg_0 = num_major_mergers >= 1

# %%
print('The number of major mergers', sum(major_merg_0)) # fill in the sum after the comma

print('The total number of major mergers at 0 is', len(num_major_mergers))
# Out:
# The number of major mergers 241
# The total number of major mergers at 0 is 10000

# %%
num_major_mergers_44= data2['Number of Major Mergers']

# %%
num_major_mergers_44
# Out:
# 0       1
# 1       4
# 2       0
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    0
# 9998    0
# 9999    0
# Name: Number of Major Mergers, Length: 10000, dtype: int64

# %%
major_merg_44 = num_major_mergers_44 >= 1

# %%
print('The number of major mergers at .44 z', sum(major_merg_44)) # fill in the sum after the comma

print('The total number of major mergers at 44 is', len(num_major_mergers_44))
# Out:
# The number of major mergers at .44 z 237
# The total number of major mergers at 44 is 10000

# %%
Time = ['13.8 [Gyr]', '4.7 [Gyr]', '[7.9][Gyr']
num_mergers = [sum(major_merg_0), sum(major_merg_44), sum(major_merg_1)] 
colors= ['orange', 'lime', 'purple']
plt.bar(Time, num_mergers, color = colors,)
plt.title ('Time vs. Number')
plt.xlabel(Time)
plt.ylabel('Number of Mergers')
plt.show()

# %%
num_major_mergers_1= data3['Number of Major Mergers']

# %%
num_major_mergers_1
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    0
# 9998    0
# 9999    0
# Name: Number of Major Mergers, Length: 10000, dtype: int64

# %%
major_merg_1 = num_major_mergers_1 >= 1

# %%
print('The number of major mergers at 1 z', sum(major_merg_1)) # fill in the sum after the comma

print('The total number of major mergers at 1 is', len(num_major_mergers_1))
# Out:
# The number of major mergers at 1 z 262
# The total number of major mergers at 1 is 10000

# %%
time_last_merger_0=data['Time Since Last Major Merger [Gyr]']

time_last_merger_0
# Out:
# 0       12.361172
# 1       12.698000
# 2       13.230112
# 3       13.800000
# 4       13.800000
#           ...
# 9995    13.800000
# 9996    13.800000
# 9997    13.800000
# 9998    13.800000
# 9999    13.800000
# Name: Time Since Last Major Merger [Gyr], Length: 10000, dtype: float64

# %%
last_merg_0=time_last_merger_0 < 13.8

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(,water_mass, color = 'lime',)
plt.plot(volumes,oil_mass, color = 'orange',)
plt.plot(volumes,karo_mass, color = 'r')
plt.plot(volumes,sun_mass, color = 'green')
plt.title ('Mass vs. Volume')
plt.xlabel('Volume')
plt.ylabel('Mass')
plt.show()
